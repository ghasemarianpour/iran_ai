# %% [markdown]
# # 🌳 **Alphabet_NLP_Dataset**

# %% [markdown]
# ## 🟢 **Imports**

# %%
import json
import psutil
import pandas as pd
import os
from pprint import pprint
import zipfile

from tokenizers import Tokenizer, models, trainers, pre_tokenizers, decoders, processors

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# %% [markdown]
# ## 🟢 **`JSON` to `Parquet`**

# %% [markdown]
# ### 🌿 **Alphabet_NLP_Dataset**

# %%
# Read JSON file manually
json_path = "/content/drive/MyDrive/Alphabet_NLP_Dataset.json"
with open(json_path, "r", encoding="utf-8") as f:
    dataset = json.load(f)

normalized_data = []
for item in dataset:
    new_item = item.copy()
    normalized_data.append(new_item)

df_json = pd.DataFrame(normalized_data)

# Save to Parquet format
parquet_path = "/content/drive/MyDrive/Alphabet_NLP_Dataset.parquet"
df_json.to_parquet(parquet_path, index=False)

# Load the Parquet data
df_loaded = pd.read_parquet(parquet_path)

# Display as a table
df_loaded
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                                             input_text  \
# 0                                                 سلام
# 1                                              اسم شما
# 2                          آیا بسم اللّه جزء سوره است؟
# 3                                 جامع‌ترین نام خداوند
# 4                              رحمت عام و رحمت خاص خدا
# ..                                                 ...
# 156          انتقال اطلاعات کوانتومی در بستر فیبر نوری
# 157           سکونت‌پذیری یک سیاره در منظومه تراپیست 1
# 158  پیش‌بینی نتیجه آزمایش‌های همجوشی هسته‌ای با هو...
# 159                     کتابخانه DNA جانوران در پشه‌ها
# 160                                 قدمت هرم بزرگ جیزه
#
#                                            target_text            source  \
# 0                     سلام! چطور می‌تونم کمکتون کنم؟ 😊               ARK
# 1    من یک مدل زبانی هستم با نام **آرک (ARK)** که ت...               ARK
# 2    درمیان دانشمندان و علماء شیعه، اختلافى در این ...  quran.makarem.ir
# 3    در جمله‌ی «بسم اللّه»، نخست با کلمه‌ی «اسم» رو...  quran.makarem.ir
# 4    مشهور درمیان گروهى از مفسران این است که: صفت «...  quran.makarem.ir
# ..                                                 ...               ...
# 156  ### محققان برای اولین‌بار، اطلاعات کوانتومی فو...         zoomit.ir
# 157  ### واپسین امیدهای اخترشناسان؛ یکی از سیاره‌ها...         zoomit.ir
# 158  ### پیشرفت بزرگ در همجوشی هسته‌ای: هوش مصنوعی ...         zoomit.ir
# 159  ### پارک ژوراسیک درست می‌گفت: پشه‌ها واقعاً کت...         zoomit.ir
# 160  ### ادعای جنجالی یک پژوهشگر: قدمت هرم بزرگ جیز...         zoomit.ir
#
#                editor   id
# 0    Ghasem Arianpour    1
# 1    Ghasem Arianpour    2
# 2    Ghasem Arianpour    3
# 3    Ghasem Arianpour    4
# 4    Ghasem Arianpour    5
# ..                ...  ...
# 156  Ghasem Arianpour  157
# 157  Ghasem Arianpour  158
# 158  Ghasem Arianpour  159
# 159  Ghasem Arianpour  160
# 160  Ghasem Arianpour  161
#
# [161 rows x 5 columns]

# %%
dataset = pd.read_parquet("/content/drive/MyDrive/Alphabet_NLP_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)

# %% [markdown]
# ### 🌿 **Alphabet_Codex_Dataset**

# %%
zip_path = "/content/drive/MyDrive/Alphabet_Codex_Dataset.zip"
extract_folder = "/content/drive/MyDrive/Alphabet_Codex_JSONs/"
extracted_folder = "/content/drive/MyDrive/Alphabet_Codex_JSONs/Alphabet_Codex_Dataset/"

if not os.path.exists(zip_path):
    print(f"Error: Zip file not found at {zip_path}")
else:
    print(f"Zip file found at {zip_path}")

os.makedirs(extract_folder, exist_ok=True)
print(f"Extraction base folder created/exists at {extract_folder}")

try:
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_folder)
    print(f"Successfully extracted zip file contents to {extract_folder}")
except Exception as e:
    print(f"Error during zip extraction: {e}")

# Debugging: List contents of the base extraction folder
print("Contents of base extraction folder (extract_folder):")
base_extracted_contents = os.listdir(extract_folder)
if not base_extracted_contents:
    print("  (Folder is empty)")
else:
    for item in base_extracted_contents:
        print(f"  - {item}")

# Ensure the 'extracted_folder' (where JSONs are expected) also exists
os.makedirs(extracted_folder, exist_ok=True)
print(f"JSON source folder confirmed/created at {extracted_folder}")

# Filter for JSON files directly in the 'extracted_folder'
json_files = [f for f in os.listdir(extracted_folder) if f.endswith('.json')]

# Debugging: Print found JSON files
if not json_files:
    print("No JSON files found in the specified JSON source folder (extracted_folder).")
else:
    print(f"Found {len(json_files)} JSON files: {json_files}")

all_data = []

for file_name in json_files:
    json_path = os.path.join(extracted_folder, file_name)
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
        if isinstance(data, list):
            all_data.extend(data)
        elif isinstance(data, dict):
            all_data.append(data)

df_json = pd.DataFrame(all_data)

parquet_path = os.path.join("/content/drive/MyDrive/", "Alphabet_Codex_Dataset.parquet")
df_json.to_parquet(parquet_path, index=False)

df_loaded = pd.read_parquet(parquet_path)

df_loaded.head()
# Out:
# Mounted at /content/drive
# Zip file found at /content/drive/MyDrive/Alphabet_Codex_Dataset.zip
# Extraction base folder created/exists at /content/drive/MyDrive/Alphabet_Codex_JSONs/
# Successfully extracted zip file contents to /content/drive/MyDrive/Alphabet_Codex_JSONs/
# Contents of base extraction folder (extract_folder):
#   - Alphabet_Codex_Dataset
# JSON source folder confirmed/created at /content/drive/MyDrive/Alphabet_Codex_JSONs/Alphabet_Codex_Dataset/
# Found 23 JSON files: ['Android.json', 'Assembly.json', 'C#.json', 'C.json', 'C++.json', 'CMD.json', 'CSS.json', 'Django.json', 'Flask.json', 'HTML.json', 'Java.json', 'JavaScript.json', 'jQuery.json', 'Kotlin.json', 'Laravel.json', 'Node.js.json', 'PHP.json', 'Python.json', 'PyTorch.json', 'SmallBasic.json', 'SQL.Server.json', 'TensorFlow.&.Keras.json', 'TypeScript.json']
#                                           input_text  \
# 0  اندروید (Android) چیست و چرا برنامه‌نویسی اندر...
# 1           آشنایی با اکوسیستم اندروید و نسخه‌های آن
# 2                                  اندروید (Android)
# 3                               برنامه‌نویسی اندروید
# 4                     فرگمنت در برنامه‌نویسی اندروید
#
#                                          target_text                  source  \
# 0  اندروید (Android) یک سیستم‌عامل مبتنی‌بر لینوک...                 ChatGPT
# 1  اکوسیستم اندروید، مجموعه‌ای از سیستم‌عامل، ابز...                 ChatGPT
# 2  اندروید (Android)، سیستم‌عامل (Operating Syste...  iairan.ir/Neuromorphic
# 3  توسعه‌ی اپلیکیشن درواقع فرآیند گام‌به‌گامی است...  iairan.ir/Neuromorphic
# 4  در توسعه‌ی نرم‌افزارهای مدرن اندروید، استفاده ...       blog.faradars.org
#
#              editor  id
# 0  Ghasem Arianpour   1
# 1  Ghasem Arianpour   2
# 2  Ghasem Arianpour   3
# 3  Ghasem Arianpour   4
# 4  Ghasem Arianpour   5

# %%
dataset = pd.read_parquet("/content/drive/MyDrive/Alphabet_Codex_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🔢 Number of samples: 150
# 📝 Total number of tokens: 31418

# %% [markdown]
# ### 🌿 **Alphabet_Science_Dataset**

# %%
zip_path = "/content/drive/MyDrive/Alphabet_Science_Dataset.zip"
extract_folder = "/content/drive/MyDrive/Alphabet_Science_JSONs/"
extracted_folder = "/content/drive/MyDrive/Alphabet_Science_JSONs/Alphabet_Science_Dataset/"

if not os.path.exists(zip_path):
    print(f"Error: Zip file not found at {zip_path}")
else:
    print(f"Zip file found at {zip_path}")

os.makedirs(extract_folder, exist_ok=True)
print(f"Extraction base folder created/exists at {extract_folder}")

try:
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_folder)
    print(f"Successfully extracted zip file contents to {extract_folder}")
except Exception as e:
    print(f"Error during zip extraction: {e}")

# Debugging: List contents of the base extraction folder
print("Contents of base extraction folder (extract_folder):")
base_extracted_contents = os.listdir(extract_folder)
if not base_extracted_contents:
    print("  (Folder is empty)")
else:
    for item in base_extracted_contents:
        print(f"  - {item}")

# Ensure the 'extracted_folder' (where JSONs are expected) also exists
os.makedirs(extracted_folder, exist_ok=True)
print(f"JSON source folder confirmed/created at {extracted_folder}")

# Filter for JSON files directly in the 'extracted_folder'
json_files = [f for f in os.listdir(extracted_folder) if f.endswith('.json')]

# Debugging: Print found JSON files
if not json_files:
    print("No JSON files found in the specified JSON source folder (extracted_folder).")
else:
    print(f"Found {len(json_files)} JSON files: {json_files}")

all_data = []

for file_name in json_files:
    json_path = os.path.join(extracted_folder, file_name)
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
        if isinstance(data, list):
            all_data.extend(data)
        elif isinstance(data, dict):
            all_data.append(data)

df_json = pd.DataFrame(all_data)

parquet_path = os.path.join("/content/drive/MyDrive/", "Alphabet_Science_Dataset.parquet")
df_json.to_parquet(parquet_path, index=False)

df_loaded = pd.read_parquet(parquet_path)

df_loaded.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Zip file found at /content/drive/MyDrive/Alphabet_Science_Dataset.zip
# Extraction base folder created/exists at /content/drive/MyDrive/Alphabet_Science_JSONs/
# Successfully extracted zip file contents to /content/drive/MyDrive/Alphabet_Science_JSONs/
# Contents of base extraction folder (extract_folder):
#   - Alphabet_Science_Dataset
# JSON source folder confirmed/created at /content/drive/MyDrive/Alphabet_Science_JSONs/Alphabet_Science_Dataset/
# Found 22 JSON files: ['Aerospace.json', 'Agriculture.json', 'AI.json', 'Astrophysics.json', 'Botany.json', 'Chemistry.json', 'Economic.json', 'Electricity.json', 'Genetic.json', 'Geology.json', 'Mathematics.json', 'Mechanic.json', 'Medicine.json', 'Midwifery.json', 'Nanotechnology.json', 'Nerves.json', 'Nuclear.Physics.json', 'Pharmacy.json', 'Physics.json', 'Psychology.json', 'Quantum.Physics.json', 'Universe.json']
#                                  input_text  \
# 0  مهندسی هوافضا چیست و چه کاربردهایی دارد؟
# 1                     تاریخچه مهندسی هوافضا
# 2
# 3         هوش مصنوعی چیست و چرا اهمیت دارد؟
# 4                        تاریخچه هوش مصنوعی
#
#                                          target_text   source  \
# 0  مهندسی هوافضا شاخه‌ای از مهندسی است که به طراح...  ChatGPT
# 1  مهندسی هوافضا با ریشه در قرن نوزدهم و اوایل قر...  ChatGPT
# 2                                                     ChatGPT
# 3  هوش مصنوعی (Artificial Intelligence یا AI) شاخ...  ChatGPT
# 4  هوش مصنوعی به‌عنوان شاخه‌ای از علوم کامپیوتر ا...  ChatGPT
#
#              editor  id
# 0  Ghasem Arianpour   1
# 1  Ghasem Arianpour   2
# 2  Ghasem Arianpour   1
# 3  Ghasem Arianpour   1
# 4  Ghasem Arianpour   2

# %%
dataset = pd.read_parquet("/content/drive/MyDrive/Alphabet_Science_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🔢 Number of samples: 161
# 📝 Total number of tokens: 24365

# %% [markdown]
# ### 🌿 **Alphabet_Technology_Dataset**

# %%
zip_path = "/content/drive/MyDrive/Alphabet_Technology_Dataset.zip"
extract_folder = "/content/drive/MyDrive/Alphabet_Technology_JSONs/"
extracted_folder = "/content/drive/MyDrive/Alphabet_Technology_JSONs/Alphabet_Technology_Dataset/"

if not os.path.exists(zip_path):
    print(f"Error: Zip file not found at {zip_path}")
else:
    print(f"Zip file found at {zip_path}")

os.makedirs(extract_folder, exist_ok=True)
print(f"Extraction base folder created/exists at {extract_folder}")

try:
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_folder)
    print(f"Successfully extracted zip file contents to {extract_folder}")
except Exception as e:
    print(f"Error during zip extraction: {e}")

# Debugging: List contents of the base extraction folder
print("Contents of base extraction folder (extract_folder):")
base_extracted_contents = os.listdir(extract_folder)
if not base_extracted_contents:
    print("  (Folder is empty)")
else:
    for item in base_extracted_contents:
        print(f"  - {item}")

# Ensure the 'extracted_folder' (where JSONs are expected) also exists
os.makedirs(extracted_folder, exist_ok=True)
print(f"JSON source folder confirmed/created at {extracted_folder}")

# Filter for JSON files directly in the 'extracted_folder'
json_files = [f for f in os.listdir(extracted_folder) if f.endswith('.json')]

# Debugging: Print found JSON files
if not json_files:
    print("No JSON files found in the specified JSON source folder (extracted_folder).")
else:
    print(f"Found {len(json_files)} JSON files: {json_files}")

all_data = []

for file_name in json_files:
    json_path = os.path.join(extracted_folder, file_name)
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
        if isinstance(data, list):
            all_data.extend(data)
        elif isinstance(data, dict):
            all_data.append(data)

df_json = pd.DataFrame(all_data)

parquet_path = os.path.join("/content/drive/MyDrive/", "Alphabet_Technology_Dataset.parquet")
df_json.to_parquet(parquet_path, index=False)

df_loaded = pd.read_parquet(parquet_path)

df_loaded.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Zip file found at /content/drive/MyDrive/Alphabet_Technology_Dataset.zip
# Extraction base folder created/exists at /content/drive/MyDrive/Alphabet_Technology_JSONs/
# Successfully extracted zip file contents to /content/drive/MyDrive/Alphabet_Technology_JSONs/
# Contents of base extraction folder (extract_folder):
#   - Alphabet_Technology_Dataset
# JSON source folder confirmed/created at /content/drive/MyDrive/Alphabet_Technology_JSONs/Alphabet_Technology_Dataset/
# Found 10 JSON files: ['AVR.Microcontroller.json', 'BIOS.json', 'CCNA.json', 'CMS.json', 'Computer.json', 'Kali.Linux.json', 'Mobile.json', 'Office.json', 'Photoshop.json', 'Self-control.json']
#                                input_text  \
# 0  میکروکنترلر و تفاوت آن با میکروپروسسور
# 1          معرفی خانواده AVR و تاریخچه آن
# 2                             میکروکنترلر
# 3                  معماری میکروکنترلر AVR
# 4                  ساختار میکروکنترلر AVR
#
#                                          target_text                  source  \
# 0  میکروکنترلر یک مدار مجتمع است که شامل پردازنده...                 ChatGPT
# 1  خانواده‌ی AVR مجموعه‌ای از میکروکنترلرهای ۸ بی...                 ChatGPT
# 2  میکروکنترلرها نوعی چیپ الکترونیکی قابل برنامه‌...  iairan.ir/Neuromorphic
# 3  در میکروکنترلر AVR از دو نوع معماری بهره برده ...  iairan.ir/Neuromorphic
# 4  برخی از اجزای تشکیل‌دهنده‌ی میکروکنترلر AVR به...  iairan.ir/Neuromorphic
#
#              editor  id
# 0  Ghasem Arianpour   1
# 1  Ghasem Arianpour   2
# 2  Ghasem Arianpour   3
# 3  Ghasem Arianpour   4
# 4  Ghasem Arianpour   5

# %%
dataset = pd.read_parquet("/content/drive/MyDrive/Alphabet_Technology_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🔢 Number of samples: 82
# 📝 Total number of tokens: 10086

# %% [markdown]
# ### 🌿 **Alphabet_Quran_Dataset**

# %%
json_path = "/content/drive/MyDrive/Quran.json"

if not os.path.exists(json_path):
    print(f"Error: JSON file not found at {json_path}")
else:
    print(f"JSON file found at {json_path}")

with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)

if isinstance(data, dict):
    all_data = [data]
elif isinstance(data, list):
    all_data = data
else:
    raise ValueError("فرمت فایل JSON ناشناخته است!")

df_json = pd.DataFrame(all_data)

parquet_path = "/content/drive/MyDrive/Alphabet_Quran_Dataset.parquet"
df_json.to_parquet(parquet_path, index=False)
print(f"Dataset saved to {parquet_path}")

df_loaded = pd.read_parquet(parquet_path)
df_loaded.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# JSON file found at /content/drive/MyDrive/Quran.json
# Dataset saved to /content/drive/MyDrive/Alphabet_Quran_Dataset.parquet
#            input_text                                        target_text  \
# 0  سوره فاتحه - آیه 1  ### سوره‌ی فاتحه - آیه‌ی 1\n**بِسْمِ اللَّهِ ا...
# 1  سوره فاتحه - آیه 2  ### سوره‌ی فاتحه - آیه‌ی 2\n**الْحَمْدُ لِلَّه...
# 2  سوره فاتحه - آیه 3  ### سوره‌ی فاتحه - آیه‌ی 3\n**الرَّحْمَٰنِ الر...
# 3  سوره فاتحه - آیه 4  ### سوره‌ی فاتحه - آیه‌ی 4\n**مَالِكِ يَوْمِ ا...
# 4  سوره فاتحه - آیه 5  ### سوره‌ی فاتحه - آیه‌ی 5\n**إِيَّاكَ نَعْبُد...
#
#                source            editor  id
# 0  wiki.ahlolbait.com  Ghasem Arianpour   1
# 1  wiki.ahlolbait.com  Ghasem Arianpour   2
# 2  wiki.ahlolbait.com  Ghasem Arianpour   3
# 3  wiki.ahlolbait.com  Ghasem Arianpour   4
# 4  wiki.ahlolbait.com  Ghasem Arianpour   5

# %%
dataset = pd.read_parquet("/content/drive/MyDrive/Alphabet_Quran_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🔢 Number of samples: 14
# 📝 Total number of tokens: 5795

# %% [markdown]
# ### 🌿 **Alphabet_Jurisprudence_Dataset**

# %%
json_path = "/content/drive/MyDrive/Jurisprudence.json"

if not os.path.exists(json_path):
    print(f"Error: JSON file not found at {json_path}")
else:
    print(f"JSON file found at {json_path}")

with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)

if isinstance(data, dict):
    all_data = [data]
elif isinstance(data, list):
    all_data = data
else:
    raise ValueError("فرمت فایل JSON ناشناخته است!")

df_json = pd.DataFrame(all_data)

parquet_path = "/content/drive/MyDrive/Alphabet_Jurisprudence_Dataset.parquet"
df_json.to_parquet(parquet_path, index=False)
print(f"Dataset saved to {parquet_path}")

df_loaded = pd.read_parquet(parquet_path)
df_loaded.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# JSON file found at /content/drive/MyDrive/Jurisprudence.json
# Dataset saved to /content/drive/MyDrive/Alphabet_Jurisprudence_Dataset.parquet
#                              input_text  \
# 0  وضو، غسل و تیمم: تعریف و شرایط هر یک
# 1             تفاوت بین مکلَّف و مکلِّف
# 2              تفاوت فقیه با مرجع تقلید
# 3                      شرایط مرجع تقلید
# 4             مفهوم عدالت در مرجع تقلید
#
#                                          target_text  \
# 0  وضو عملی است که با شستن یا مسح اعضای خاص همراه...
# 1  ### 1️⃣ مکلَّف (فتحه روی لام مشدّد)\nکسی که با...
# 2  ### تفاوت فقیه با مرجع تقلید:\nفقیه مورد رجوع ...
# 3  ### شرایط مرجع تقلید:\n1. اجتهاد\n2. عقل و بلو...
# 4  عدالت در مرجع تقلید، حالتی نفسانی است که انسان...
#
#                                               source            editor  id
# 0  Jurisprudence Lesson Notes - Mohammad Hossein ...  Ghasem Arianpour   1
# 1                                            ChatGPT  Ghasem Arianpour   2
# 2  Jurisprudence Lesson Notes - Mohammad Hossein ...  Ghasem Arianpour   3
# 3  Jurisprudence Lesson Notes - Mohammad Hossein ...  Ghasem Arianpour   4
# 4  Jurisprudence Lesson Notes - Mohammad Hossein ...  Ghasem Arianpour   5

# %%
dataset = pd.read_parquet("/content/drive/MyDrive/Alphabet_Jurisprudence_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🔢 Number of samples: 15
# 📝 Total number of tokens: 662

# %% [markdown]
# ### 🌿 **Alphabet_Philologia_Dataset**

# %%
zip_path = "/content/drive/MyDrive/Alphabet_Philologia_Dataset.zip"
extract_folder = "/content/drive/MyDrive/Alphabet_Philologia_JSONs/"
extracted_folder = "/content/drive/MyDrive/Alphabet_Philologia_JSONs/Alphabet_Philologia_Dataset/"

if not os.path.exists(zip_path):
    print(f"Error: Zip file not found at {zip_path}")
else:
    print(f"Zip file found at {zip_path}")

os.makedirs(extract_folder, exist_ok=True)
print(f"Extraction base folder created/exists at {extract_folder}")

try:
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_folder)
    print(f"Successfully extracted zip file contents to {extract_folder}")
except Exception as e:
    print(f"Error during zip extraction: {e}")

# Debugging: List contents of the base extraction folder
print("Contents of base extraction folder (extract_folder):")
base_extracted_contents = os.listdir(extract_folder)
if not base_extracted_contents:
    print("  (Folder is empty)")
else:
    for item in base_extracted_contents:
        print(f"  - {item}")

# Ensure the 'extracted_folder' (where JSONs are expected) also exists
os.makedirs(extracted_folder, exist_ok=True)
print(f"JSON source folder confirmed/created at {extracted_folder}")

# Filter for JSON files directly in the 'extracted_folder'
json_files = [f for f in os.listdir(extracted_folder) if f.endswith('.json')]

# Debugging: Print found JSON files
if not json_files:
    print("No JSON files found in the specified JSON source folder (extracted_folder).")
else:
    print(f"Found {len(json_files)} JSON files: {json_files}")

all_data = []

for file_name in json_files:
    json_path = os.path.join(extracted_folder, file_name)
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
        if isinstance(data, list):
            all_data.extend(data)
        elif isinstance(data, dict):
            all_data.append(data)

df_json = pd.DataFrame(all_data)

parquet_path = os.path.join("/content/drive/MyDrive/", "Alphabet_Philologia_Dataset.parquet")
df_json.to_parquet(parquet_path, index=False)

df_loaded = pd.read_parquet(parquet_path)

df_loaded.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Zip file found at /content/drive/MyDrive/Alphabet_Philologia_Dataset.zip
# Extraction base folder created/exists at /content/drive/MyDrive/Alphabet_Philologia_JSONs/
# Successfully extracted zip file contents to /content/drive/MyDrive/Alphabet_Philologia_JSONs/
# Contents of base extraction folder (extract_folder):
#   - Alphabet_Philologia_Dataset
# JSON source folder confirmed/created at /content/drive/MyDrive/Alphabet_Philologia_JSONs/Alphabet_Philologia_Dataset/
# Found 3 JSON files: ['Cuneiform.json', 'English.json', 'Hieroglyphic.json']
#                input_text                                        target_text  \
# 0                 خط میخی  خط میخی یکی از قدیمی‌ترین نظام‌های نوشتاری جها...
# 1  تاریخچه پیدایش خط میخی  خط میخی، نخستین بار در حدود ۳۲۰۰ سال پیش از می...
# 2        زمان‌های انگلیسی  سه نوع زمان در زبان انگلیسی وجود دارد که وقوع ...
# 3   زمان حال ساده انگلیسی  از زمان «حال ساده» (Simple Present) برای بیان ...
# 4      گذشته ساده انگلیسی  زمان «گذشته‌ی ساده» (Simple Past) به عملی دلال...
#
#               source            editor  id
# 0            ChatGPT  Ghasem Arianpour   1
# 1            ChatGPT  Ghasem Arianpour   2
# 2  blog.faradars.org  Ghasem Arianpour   1
# 3  blog.faradars.org  Ghasem Arianpour   2
# 4  blog.faradars.org  Ghasem Arianpour   3

# %%
dataset = pd.read_parquet("/content/drive/MyDrive/Alphabet_Philologia_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🔢 Number of samples: 20
# 📝 Total number of tokens: 2313

# %% [markdown]
# ## 🟢 **EDA**

# %% [markdown]
# ### 🔴 Exploring the Dataset

# %%
base_path = "/content/drive/MyDrive/"

files = [
    "Alphabet_NLP_Dataset.parquet",
    "Alphabet_Codex_Dataset.parquet",
    "Alphabet_Jurisprudence_Dataset.parquet",
    "Alphabet_Quran_Dataset.parquet",
    "Alphabet_Science_Dataset.parquet",
    "Alphabet_Technology_Dataset.parquet",
    "Alphabet_Philologia_Dataset.parquet"
]

datasets = [pd.read_parquet(base_path + file) for file in files]

dataset = pd.concat(datasets, ignore_index=True)

dataset.head()
print("🔢 Number of samples:", len(dataset))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🔢 Number of samples: 603

# %%
sample = dataset.sample(n=1)
pprint(sample.to_dict(orient="records")[0])
# Out:
# {'editor': 'Ghasem Arianpour',
#  'id': 81,
#  'input_text': 'پیشرفت\u200cهای بزرگ در ژنتیک',
#  'source': 'worldhistory.org',
#  'target_text': '### ✨ پیشرفت\u200cهای بزرگ در ژنتیک\n'
#                 'در سال ۱۸۵۹، طبیعت\u200cشناس انگلیسی - چارلز داروین - کتاب '
#                 '«نسبت گونه\u200cها از طریق انتخاب طبیعی» را منتشر کرد، که در '
#                 'آن، نظریه\u200cی خود درباره\u200cی «انتخاب طبیعی» را توضیح '
#                 'داد (براساس این نظریه، موجودات زنده، احتمال بیشتری برای بقا و '
#                 'تولید مثل دارند، اگر ویژگی\u200cهای به ارث رسیده\u200cای '
#                 'داشته باشند که امکان سازگاری با محیط را فراهم کند.)، که '
#                 'زمینه\u200cساز فهم مدرن ژنتیک شد. بااین\u200cحال، داروین قادر '
#                 'نبود مکانیزم\u200cهای پشت صفات ارثی را توضیح دهد که موجب '
#                 'تغییر موجودات زنده درطول زمان می\u200cشوند.\n'
#                 '\n'
#                 'کشف «ژن\u200cهای غالب و مغلوب»، به یک راهب اتریشی - گرگور '
#                 'مندل (۱۸۲۲–۱۸۸۴) - نسبت داده می\u200cشود. مندل با استفاده از '
#                 'گیاه نخود، ویژگی\u200cهای مختلف گیاه - مانند رنگ، ارتفاع و '
#                 'گل\u200cها - که از نسلی به نسل بعد منتقل می\u200cشدند را '
#                 'شناسایی کرد. او همچنین نتیجه گرفت که صفات (یا فنوتیپ\u200cها) '
#                 'به\u200cصورت جفتی ظاهر می\u200cشوند (یکی از هر والد)، و یک '
#                 'صفت چون بیشتر دیده می\u200cشود، در نسل بعد، غالب خواهد بود. '
#                 'همچنین، انتقال این صفات، الگوهای مشخصی دارد. این کشفیات بعدها '
#                 'به\u200cعنوان «قوانین مندل در ژنتیک» شناخته شد. '
#                 'یافته\u200cهای مندل در ابتدا توسط سایر دانشمندان شناخته نشد، '
#                 'اما در سال ۱۹۰۰ دوباره مطرح شد و ژنتیک را به یک رشته\u200cی '
#                 'علمی مستقل تبدیل کرد.\n'
#                 '\n'
#                 'پایان قرن نوزدهم و آغاز قرن بیستم شاهد کشفیات دیگری بود که '
#                 'برای مطالعه\u200cی «ژنتیک مرکزی» بودند. «کروموزوم\u200cها» که '
#                 '«ماده\u200cی ژنتیکی» را در خود دارند، توسط والتر فلمینگ '
#                 '(۱۸۴۳–۱۹۰۵) - زیست\u200cشناس آلمانی - در سال ۱۸۸۲ کشف شدند؛ '
#                 'او همچنین «میتوز (تقسیم سلولی)» را شناسایی کرد. در سال ۱۹۰۶، '
#                 'ویلیام بیتسون (۱۸۶۱–۱۹۲۶) - زیست\u200cشناس انگلیسی - اولین '
#                 'کسی بود که اصطلاح «ژنتیک» را برای توصیف مطالعه\u200cی «وراثت» '
#                 'به\u200cکار برد. ویلهلم یوهانسِن (۱۸۵۷–۱۹۲۷) - زیست\u200cشناس '
#                 'دانمارکی - استدلال کرد که عوامل محیطیِ همراه با وراثت، '
#                 'تعیین\u200cکننده\u200cی تنوع ژنی هستند و اصطلاحات ژن، ژنوتیپ '
#                 '(ترکیب ژنتیکی سلول) و فنوتیپ (ویژگی\u200cهای جسمانی ناشی از '
#                 'تعامل ژنوتیپ\u200cها با محیط) را ابداع کرد. والتر استنبورو '
#                 'ساتن (۱۸۷۷–۱۹۱۶) - ژنتیکدان آمریکایی - با تحقیقات خود روی '
#                 'ملخ\u200cها، نقش کروموزوم\u200cها در تولید مثل جنسی را روشن '
#                 'کرد. نتایج مطالعه\u200cی او که در ۱۹۰۲ منتشر شد، نشان داد که '
#                 'کروموزوم\u200cها در جفت\u200cها وجود دارند و سلول\u200cهای '
#                 'اسپرم و تخمک، هرکدام یک جفت کروموزوم دارند.\n'
#                 '\n'
#                 'به\u200cگفته\u200cی ژان گایون در کتاب «از مندل تا '
#                 'اپی\u200cژنتیک: تاریخچه\u200cی ژنتیک»، نیمه\u200cی اول قرن '
#                 'بیستم تحت سلطه\u200cی «ژنتیک کلاسیک» بود: «ژن همزمان واحد '
#                 'عملکرد و انتقال، واحد بازترکیب و واحد جهش است». تحقیقات '
#                 'پیشروِ توماس مورگان (۱۸۶۶–۱۹۴۵) با استفاده از مگسِ میوه، '
#                 'رابطه\u200cی میان کروموزوم\u200cها و ژن\u200cها در انتقال '
#                 'ویژگی\u200cهای جسمانی بین نسل\u200cها را نشان داد که منجر به '
#                 '«نظریه\u200cی کروموزومی وراثت» شد؛ ایده\u200cای که '
#                 'ژن\u200cهای موجود در کروموزوم\u200cها، اجزای بنیادی وراثت '
#                 'هستند. او نشان داد که کروموزوم\u200cهای مشخص، ژن\u200cهای '
#                 'مشخصی را حمل می\u200cکنند که البته همیشه به نسل بعد منتقل '
#                 'نمی\u200cشوند. مورگان همچنین با نظریه\u200cی «بازترکیب '
#                 'ژنتیکی» شناخته می\u200cشود: «ماده\u200cی ژنتیکی می\u200cتواند '
#                 'به مولکول\u200cهای DNA منتقل شود و بدین\u200cترتیب یک ژن جدید '
#                 'شکل بگیرد.» او به\u200cعنوان پدر ژنتیک کلاسیک شناخته شد و در '
#                 'سال ۱۹۳۳ جایزه\u200cی نوبل پزشکی را دریافت کرد.\n'
#                 '\n'
#                 'تحقیقات ژنتیک کلاسیک، نیمه\u200cی اول قرن بیستم را تسلط داشت. '
#                 '«نوکلئوتیدها (واحدهای سازنده\u200cی DNA)» در سال ۱۹۲۹ توسط '
#                 'فبوس آ. لوون (۱۸۶۹–۱۹۴۰) - شیمی\u200cدان آمریکایی - کشف شدند. '
#                 'لینوس پالینگ (۱۹۰۱–۱۹۹۴) - شیمی\u200cدان آمریکایی - با بررسی '
#                 'مشکلات مربوط به کم\u200cخونی داسی\u200cشکل، توضیحاتی برای '
#                 'اختلالات ژنتیکی ارثی ارائه داد که غالباً ناشی از تغییرات در '
#                 'پروتئین\u200cها بودند. ژنتیک کلاسیک تلاش داشت تا ساختار DNA '
#                 'را بهتر درک کند و مطمئن بود که DNA کلید تمام مواد ژنتیکی است. '
#                 'تا دهه\u200cی ۱۹۵۰، ژنتیک مدرن برای فهم عملکرد ژن\u200cها و '
#                 'نقش آن\u200cها در فرآیند وراثت آغاز شد.\n'
#                 '\n'
#                 'در سال ۱۹۵۳، دو زیست\u200cشناس مولکولی - جیمز واتسون '
#                 '(۱۹۲۸–۲۰۲۵) آمریکایی، و فرانسیس کریک (۱۹۱۶–۲۰۰۴) انگلیسی - با '
#                 'کمک تصویر DNA توسط رزالیند فرانکلین، برای اولین بار «ساختار '
#                 'مارپیچ دوگانه\u200cی DNA» را ترسیم کردند. کشف آن\u200cها نشان '
#                 'داد که DNA حامل مواد ژنتیکی وراثت است و ساختار آن، همراه با '
#                 'دیگر مواد، خودتکثیر شونده است. این کشفیات، پایه\u200cهای '
#                 '«زیست\u200cشناسی مولکولی مدرن» را شکل داد. هردو جایزه\u200cی '
#                 'نوبل پزشکی ۱۹۶۲ را دریافت کردند.\n'
#                 '\n'
#                 'در سال ۱۹۵۶، ورنون ام. اینگرام (۱۹۲۴–۲۰۰۶) - بیوشیمیست '
#                 'آمریکایی و پدر پزشکی مولکولی - در تحقیقات خود درباره\u200cی '
#                 'کم\u200cخونی داسی\u200cشکل نشان داد که جهشِ یک حرف در کد '
#                 'ژنتیکی DNA برای ایجاد یک بیماری ارثی کافی است، و این امکان را '
#                 'فراهم کرد که راهکارهای پیشگیری و درمان برای بیماری\u200cهای '
#                 'مشابه؛ مانند هموفیلی و فیبروز کیستی ارائه شود. کمی بعد، اولین '
#                 'ناهنجاری کروموزومی انسان در افراد مبتلا به سندروم داون '
#                 'شناسایی شد. این اختلال ژنتیکی، نتیجه\u200cی کروموزومِ اضافه '
#                 'بود که با بررسی مستقیم کروموزوم\u200cها کشف شد.\n'
#                 '\n'
#                 'ناهنجاری\u200cهای کروموزومی که منجر به نقص\u200cهای مادرزادی '
#                 'می\u200cشوند، و همینطور جنسیت کودکان، ازجمله زمینه\u200cهای '
#                 'پژوهشی بودند که دانشمندان در دهه\u200cهای بعدی دنبال کردند. '
#                 'همچنین «زیست\u200cفناوری» به\u200cعنوان رشته\u200cای نوظهور '
#                 'شکل گرفت که به بررسی شناسایی جهش\u200cها و اثرات آن\u200cها '
#                 'بر DNA پرداخت. تحقیقات بعدی منجر به توسعه\u200cی انسولین '
#                 'انسانی و هورمون رشد انسانی (۱۹۷۹)، شبیه\u200cسازی یا کلونینگ '
#                 '(۱۹۸۱، که منجر به خلق گوسفند دالی شد)، و درمان ژنتیکی انسان '
#                 '(۱۹۹۰) شد.'}

# %% [markdown]
# ### 🔴 Measuring RAM Usage After Dataset Loading

# %%
base_path = "/content/drive/MyDrive/"

files = [
    "Alphabet_NLP_Dataset.parquet",
    "Alphabet_Codex_Dataset.parquet",
    "Alphabet_Jurisprudence_Dataset.parquet",
    "Alphabet_Quran_Dataset.parquet",
    "Alphabet_Science_Dataset.parquet",
    "Alphabet_Technology_Dataset.parquet",
    "Alphabet_Philologia_Dataset.parquet"
]

process = psutil.Process(os.getpid())
ram_before = process.memory_info().rss  # bytes

datasets = [pd.read_parquet(base_path + file) for file in files]
dataset = pd.concat(datasets, ignore_index=True)

ram_after = process.memory_info().rss  # bytes

ram_used = ram_after - ram_before
print(f"🔹 RAM used for loading merged dataset: {ram_used / (1024**2):.2f} MB")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🔹 RAM used for loading merged dataset: 2.70 MB
# 🔢 Number of samples: 603

# %%
train_full = list(dataset["target_text"])
print(f"🔹 Number of training samples: {len(train_full)}")
# Out:
# 🔹 Number of samples: 603

# %% [markdown]
# ### 🔴 Tokenization

# %%
base_path = "/content/drive/MyDrive/"

files = [
    "Alphabet_NLP_Dataset.parquet",
    "Alphabet_Codex_Dataset.parquet",
    "Alphabet_Jurisprudence_Dataset.parquet",
    "Alphabet_Quran_Dataset.parquet",
    "Alphabet_Science_Dataset.parquet",
    "Alphabet_Technology_Dataset.parquet",
    "Alphabet_Philologia_Dataset.parquet"
]

datasets = [pd.read_parquet(base_path + file) for file in files]
dataset = pd.concat(datasets, ignore_index=True)

texts = []

for _, row in dataset.iterrows():
    texts.append(str(row["input_text"]).replace("\u200c", "<ZWNJ>"))
    texts.append(str(row["target_text"]).replace("\u200c", "<ZWNJ>"))

tokenizer = Tokenizer(models.BPE(unk_token="|<unk>|"))

tokenizer.pre_tokenizer = pre_tokenizers.ByteLevel(
    add_prefix_space=True
)

trainer = trainers.BpeTrainer(
    vocab_size=10_000,
    special_tokens=["|<unk>|", "<|endoftext|>"],
    min_frequency=2,
)

tokenizer.train_from_iterator(texts, trainer)

tokenizer.decoder = decoders.ByteLevel(
    add_prefix_space=True,
    clean_up_tokenization_spaces=False
)

total_tokens = 0

for text in texts:
    total_tokens += len(tokenizer.encode(text).ids)

json_out = "/content/drive/MyDrive/bpe-tokenizer_alphabet_nlp_dataset_10,000.json"
tokenizer.save(json_out)

print("🎉 Tokenizer training complete!")
print(f"🔢 tokens: {total_tokens:,}")
print(f"🔹 Vocabulary size: {tokenizer.get_vocab_size():,} tokens")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 🎉 Tokenizer training complete!
# 🔢 Number of samples: 603
# 🔢 tokens: 268,265
# 🔹 Vocabulary size: 10,000 tokens

# %% [markdown]
# ### 🔴 Measuring RAM Usage After Tokenization

# %%
tokenizer = Tokenizer.from_file("/content/drive/MyDrive/bpe-tokenizer_alphabet_nlp_dataset_10,000.json")

# Calculate RAM usage after loading
process = psutil.Process(os.getpid())
mem_info = process.memory_info()
ram_mb = mem_info.rss / (1024 ** 2)

print(f"💾 RAM Usage after loading tokenizer: {ram_mb:.2f} MB")
# Out:
# 💾 RAM Usage after loading tokenizer: 244.83 MB

# %% [markdown]
# ### 🔴 Tokenizer Test

# %%
from tokenizers import Tokenizer

# Load the trained tokenizer
tokenizer = Tokenizer.from_file("/content/drive/MyDrive/bpe-tokenizer_alphabet_nlp_dataset_10,000.json")

# Sample text containing special tokens
sample_text = "###عنوان\n\nاین\nیک متن **مهم** با نیم‌فاصله است."

# Encode the sample text
encoded_output = tokenizer.encode(sample_text)

# Print the tokens and their decoded representation
print(f"Original text:\n{sample_text}")
print(f"Encoded tokens: {encoded_output.tokens}")
print(f"Decoded text:\n{tokenizer.decode(encoded_output.ids)}")
# Out:
# Original text:
# ###عنوان
#
# این
# یک متن **مهم** با نیم‌فاصله است.
# Encoded tokens: ['Ġ###', 'Ø¹ÙĨÙĪØ§ÙĨ', 'Ċ', 'Ċ', 'Ø§ÛĮÙĨ', 'Ċ', 'ÛĮÚ©', 'ĠÙħØªÙĨ', 'Ġ**', 'ÙħÙĩÙħ', '**', 'ĠØ¨Ø§', 'ĠÙĨ', 'ÛĮÙħ', 'âĢ', 'Į', 'Ùģ', 'Ø§ØµÙĦÙĩ', 'ĠØ§Ø³Øª', '.']
# Decoded text:
#  ###عنوان
#
# این
# یک متن **مهم** با نیم‌فاصله است.
