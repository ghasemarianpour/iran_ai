# %% [markdown]
# # 🌳 **Alphabet_NLP_Dataset**

# %% [markdown]
# ## 🟢 **Imports**

# %%
import json
import psutil
import pandas as pd
import os
from pprint import pprint

from tokenizers import Tokenizer, models, trainers, pre_tokenizers, decoders, processors

# %% [markdown]
# ## 🟢 **`JSON` to `Parquet`**

# %% [markdown]
# ### 🌿 **Alphabet_NLP_Dataset**

# %%
# Read JSON file
json_path = "raw/dataset/Alphabet_NLP_Dataset.json"

with open(json_path, "r", encoding="utf-8") as f:
    dataset = json.load(f)

normalized_data = []
for item in dataset:
    new_item = item.copy()
    normalized_data.append(new_item)

df_json = pd.DataFrame(normalized_data)

# Save to Parquet format
parquet_path = "parquet/Alphabet_NLP_Dataset.parquet"
df_json.to_parquet(parquet_path, index=False)

# Load the Parquet data
df_loaded = pd.read_parquet(parquet_path)

# Display as a table
df_loaded
# Out:
#                                             input_text  \
# 0                                                 سلام
# 1                                        مدل زبانی آرک
# 2                          آیا بسم اللّه جزء سوره است؟
# 3                                 جامع‌ترین نام خداوند
# 4                              رحمت عام و رحمت خاص خدا
# ..                                                 ...
# 157           سکونت‌پذیری یک سیاره در منظومه تراپیست 1
# 158  پیش‌بینی نتیجه آزمایش‌های همجوشی هسته‌ای با هو...
# 159                     کتابخانه DNA جانوران در پشه‌ها
# 160                                 قدمت هرم بزرگ جیزه
# 161                                خواص دعای شرف‌الشمس
#
#                                            target_text  \
# 0                     سلام! چطور می‌تونم کمکتون کنم؟ 😊
# 1    من یک **مدل زبانی** هستم با نام **آرک (ARK)** ...
# 2    در میان دانشمندان و علماء شیعه، اختلافى در این...
# 3    در جمله‌ی «بسم اللّه»، نخست با کلمه‌ی «اسم» رو...
# 4    مشهور در میان گروهى از مفسران این است که: صفت ...
# ..                                                 ...
# 157  ### واپسین امیدهای اخترشناسان؛ یکی از سیاره‌ها...
# 158  ### پیشرفت بزرگ در همجوشی هسته‌ای: هوش مصنوعی ...
# 159  ### پارک ژوراسیک درست می‌گفت: پشه‌ها واقعاً کت...
# 160  ### ادعای جنجالی یک پژوهشگر: قدمت هرم بزرگ جیز...
# 161  نگین یا انگشتر یا آویز شرف‌الشمس برای ایمنی در...
#
#                           source            editor   id
# 0                            ARK  Ghasem Arianpour    1
# 1                            ARK  Ghasem Arianpour    2
# 2               quran.makarem.ir  Ghasem Arianpour    3
# 3               quran.makarem.ir  Ghasem Arianpour    4
# 4               quran.makarem.ir  Ghasem Arianpour    5
# ..                           ...               ...  ...
# 157                    zoomit.ir  Ghasem Arianpour  158
# 158                    zoomit.ir  Ghasem Arianpour  159
# 159                    zoomit.ir  Ghasem Arianpour  160
# 160                    zoomit.ir  Ghasem Arianpour  161
# 161  Ghasem Arianpour's Notebook  Ghasem Arianpour  162
#
# [162 rows x 5 columns]

# %%
dataset = pd.read_parquet("parquet/Alphabet_NLP_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)
# Out:
# 🔢 Number of samples: 162
# 📝 Total number of tokens: 62791

# %% [markdown]
# ### 🌿 **Alphabet_Codex_Dataset**

# %%
extracted_folder = "raw/dataset/Alphabet_Codex_Dataset/"

# Filter for JSON files directly in the 'extracted_folder'
json_files = [f for f in os.listdir(extracted_folder) if f.endswith('.json')]

# Debugging: Print found JSON files
if not json_files:
    print("No JSON files found in the specified JSON source folder (extracted_folder).")
else:
    print(f"Found {len(json_files)} JSON files: {json_files}")

all_data = []

for file_name in json_files:
    json_path = os.path.join(extracted_folder, file_name)
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
        if isinstance(data, list):
            all_data.extend(data)
        elif isinstance(data, dict):
            all_data.append(data)

df_json = pd.DataFrame(all_data)

parquet_path = "parquet/Alphabet_Codex_Dataset.parquet"
os.makedirs("parquet", exist_ok=True)
df_json.to_parquet(parquet_path, index=False)

df_loaded = pd.read_parquet(parquet_path)

df_loaded.head()
# Out:
# Found 23 JSON files: ['Android.json', 'Assembly.json', 'C#.json', 'C++.json', 'C.json', 'CMD.json', 'CSS.json', 'Django.json', 'Flask.json', 'HTML.json', 'Java.json', 'JavaScript.json', 'jQuery.json', 'Kotlin.json', 'Laravel.json', 'Node.js.json', 'PHP.json', 'Python.json', 'PyTorch.json', 'SmallBasic.json', 'SQL.Server.json', 'TensorFlow.&.Keras.json', 'TypeScript.json']
#                                           input_text  \
# 0  اندروید (Android) چیست و چرا برنامه‌نویسی اندر...
# 1           آشنایی با اکوسیستم اندروید و نسخه‌های آن
# 2                                  اندروید (Android)
# 3                               برنامه‌نویسی اندروید
# 4                     فرگمنت در برنامه‌نویسی اندروید
#
#                                          target_text             source  \
# 0  اندروید (Android) یک سیستم‌عامل مبتنی‌بر لینوک...            ChatGPT
# 1  اکوسیستم اندروید، مجموعه‌ای از سیستم‌عامل، ابز...            ChatGPT
# 2  اندروید (Android)، سیستم‌عامل (Operating Syste...            ChatGPT
# 3  توسعه‌ی اپلیکیشن درواقع فرایند گام‌به‌گامی است...            ChatGPT
# 4  در توسعه‌ی نرم‌افزارهای مدرن اندروید، استفاده ...  blog.faradars.org
#
#              editor  id
# 0  Ghasem Arianpour   1
# 1  Ghasem Arianpour   2
# 2  Ghasem Arianpour   3
# 3  Ghasem Arianpour   4
# 4  Ghasem Arianpour   5

# %%
dataset = pd.read_parquet("parquet/Alphabet_Codex_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)
# Out:
# 🔢 Number of samples: 195
# 📝 Total number of tokens: 46306

# %% [markdown]
# ### 🌿 **Alphabet_Science_Dataset**

# %%
extracted_folder = "raw/dataset/Alphabet_Science_Dataset/"

# Filter for JSON files directly in the 'extracted_folder'
json_files = [f for f in os.listdir(extracted_folder) if f.endswith('.json')]

# Debugging: Print found JSON files
if not json_files:
    print("No JSON files found in the specified JSON source folder (extracted_folder).")
else:
    print(f"Found {len(json_files)} JSON files: {json_files}")

all_data = []

for file_name in json_files:
    json_path = os.path.join(extracted_folder, file_name)
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
        if isinstance(data, list):
            all_data.extend(data)
        elif isinstance(data, dict):
            all_data.append(data)

df_json = pd.DataFrame(all_data)

parquet_path = "parquet/Alphabet_Science_Dataset.parquet"
df_json.to_parquet(parquet_path, index=False)

df_loaded = pd.read_parquet(parquet_path)

df_loaded.head()
# Out:
# Found 22 JSON files: ['Aerospace.json', 'Agriculture.json', 'AI.json', 'Astrophysics.json', 'Botany.json', 'Chemistry.json', 'Economic.json', 'Electricity.json', 'Genetic.json', 'Geology.json', 'Mathematics.json', 'Mechanic.json', 'Medicine.json', 'Midwifery.json', 'Nanotechnology.json', 'Nerves.json', 'Nuclear.Physics.json', 'Pharmacy.json', 'Physics.json', 'Psychology.json', 'Quantum.Physics.json', 'Universe.json']
#                                  input_text  \
# 0  مهندسی هوافضا چیست و چه کاربردهایی دارد؟
# 1                     تاریخچه مهندسی هوافضا
# 2                                     پهپاد
# 3                               انواع پهپاد
# 4                     پهپادهای مبتنی‌بر ملخ
#
#                                          target_text             source  \
# 0  مهندسی هوافضا شاخه‌ای از مهندسی است که به طراح...            ChatGPT
# 1  مهندسی هوافضا با ریشه در قرن نوزدهم و اوایل قر...            ChatGPT
# 2  گرچه امروزه کلمه‌ی پهپاد به‌صورت گسترده استفاد...  blog.faradars.org
# 3  پهپادها ابتدا برای اهداف نظامی و صنایع هوافضا ...  blog.faradars.org
# 4  پهپادهای مبتنی‌بر ملخ، یکی از رایج‌ترین و پرکا...  blog.faradars.org
#
#              editor  id
# 0  Ghasem Arianpour   1
# 1  Ghasem Arianpour   2
# 2  Ghasem Arianpour   3
# 3  Ghasem Arianpour   4
# 4  Ghasem Arianpour   5

# %%
dataset = pd.read_parquet("parquet/Alphabet_Science_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)
# Out:
# 🔢 Number of samples: 384
# 📝 Total number of tokens: 60185

# %% [markdown]
# ### 🌿 **Alphabet_Technology_Dataset**

# %%
extracted_folder = "raw/dataset/Alphabet_Technology_Dataset/"

# Filter for JSON files directly in the 'extracted_folder'
json_files = [f for f in os.listdir(extracted_folder) if f.endswith('.json')]

# Debugging: Print found JSON files
if not json_files:
    print("No JSON files found in the specified JSON source folder (extracted_folder).")
else:
    print(f"Found {len(json_files)} JSON files: {json_files}")

all_data = []

for file_name in json_files:
    json_path = os.path.join(extracted_folder, file_name)
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
        if isinstance(data, list):
            all_data.extend(data)
        elif isinstance(data, dict):
            all_data.append(data)

df_json = pd.DataFrame(all_data)

parquet_path = "parquet/Alphabet_Technology_Dataset.parquet"
df_json.to_parquet(parquet_path, index=False)

df_loaded = pd.read_parquet(parquet_path)

df_loaded.head()
# Out:
# Found 11 JSON files: ['AVR.Microcontroller.json', 'BIOS.json', 'CCNA.json', 'CMS.json', 'Computer.json', 'Kali.Linux.json', 'Mobile.json', 'Office.json', 'Photoshop.json', 'Robotics.json', 'Self-control.json']
#                                input_text  \
# 0  میکروکنترلر و تفاوت آن با میکروپروسسور
# 1          معرفی خانواده AVR و تاریخچه آن
# 2                             میکروکنترلر
# 3                  معماری میکروکنترلر AVR
# 4                  ساختار میکروکنترلر AVR
#
#                                          target_text                  source  \
# 0  میکروکنترلر یک مدار مجتمع است که شامل پردازنده...                 ChatGPT
# 1  خانواده‌ی AVR مجموعه‌ای از میکروکنترلرهای ۸ بی...                 ChatGPT
# 2  میکروکنترلرها نوعی چیپ الکترونیکی قابل برنامه‌...  iairan.ir/neuromorphic
# 3  در میکروکنترلر AVR از دو نوع معماری بهره برده ...  iairan.ir/neuromorphic
# 4  برخی از اجزای تشکیل‌دهنده‌ی میکروکنترلر AVR به...  iairan.ir/neuromorphic
#
#              editor  id
# 0  Ghasem Arianpour   1
# 1  Ghasem Arianpour   2
# 2  Ghasem Arianpour   3
# 3  Ghasem Arianpour   4
# 4  Ghasem Arianpour   5

# %%
dataset = pd.read_parquet("parquet/Alphabet_Technology_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)
# Out:
# 🔢 Number of samples: 104
# 📝 Total number of tokens: 24350

# %% [markdown]
# ### 🌿 **Alphabet_Quran_Dataset**

# %%
json_path = "raw/dataset/Quran.json"

if not os.path.exists(json_path):
    print(f"Error: JSON file not found at {json_path}")
else:
    print(f"JSON file found at {json_path}")

with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)

if isinstance(data, dict):
    all_data = [data]
elif isinstance(data, list):
    all_data = data
else:
    raise ValueError("فرمت فایل JSON ناشناخته است!")

df_json = pd.DataFrame(all_data)

parquet_path = "parquet/Alphabet_Quran_Dataset.parquet"
df_json.to_parquet(parquet_path, index=False)
print(f"Dataset saved to {parquet_path}")

df_loaded = pd.read_parquet(parquet_path)
df_loaded.head()
# Out:
# JSON file found at raw/dataset/Quran.json
# Dataset saved to parquet/Alphabet_Quran_Dataset.parquet
#            input_text                                        target_text  \
# 0  سوره فاتحه - آیه 1  ### سوره‌ی فاتحه - آیه‌ی 1\n**بِسْمِ اللَّهِ ا...
# 1  سوره فاتحه - آیه 2  ### سوره‌ی فاتحه - آیه‌ی 2\n**الْحَمْدُ لِلَّه...
# 2  سوره فاتحه - آیه 3  ### سوره‌ی فاتحه - آیه‌ی 3\n**الرَّحْمَٰنِ الر...
# 3  سوره فاتحه - آیه 4  ### سوره‌ی فاتحه - آیه‌ی 4\n**مَالِكِ يَوْمِ ا...
# 4  سوره فاتحه - آیه 5  ### سوره‌ی فاتحه - آیه‌ی 5\n**إِيَّاكَ نَعْبُد...
#
#                source            editor  id
# 0  wiki.ahlolbait.com  Ghasem Arianpour   1
# 1  wiki.ahlolbait.com  Ghasem Arianpour   2
# 2  wiki.ahlolbait.com  Ghasem Arianpour   3
# 3  wiki.ahlolbait.com  Ghasem Arianpour   4
# 4  wiki.ahlolbait.com  Ghasem Arianpour   5

# %%
dataset = pd.read_parquet("parquet/Alphabet_Quran_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)
# Out:
# 🔢 Number of samples: 126
# 📝 Total number of tokens: 27671

# %% [markdown]
# ### 🌿 **Alphabet_Jurisprudence_Dataset**

# %%
json_path = "raw/dataset/Jurisprudence.json"

if not os.path.exists(json_path):
    print(f"Error: JSON file not found at {json_path}")
else:
    print(f"JSON file found at {json_path}")

with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)

if isinstance(data, dict):
    all_data = [data]
elif isinstance(data, list):
    all_data = data
else:
    raise ValueError("فرمت فایل JSON ناشناخته است!")

df_json = pd.DataFrame(all_data)

parquet_path = "parquet/Alphabet_Jurisprudence_Dataset.parquet"
df_json.to_parquet(parquet_path, index=False)
print(f"Dataset saved to {parquet_path}")

df_loaded = pd.read_parquet(parquet_path)
df_loaded.head()
# Out:
# JSON file found at raw/dataset/Jurisprudence.json
# Dataset saved to parquet/Alphabet_Jurisprudence_Dataset.parquet
#                              input_text  \
# 0  وضو، غسل و تیمم: تعریف و شرایط هر یک
# 1             تفاوت بین مکلَّف و مکلِّف
# 2              تفاوت فقیه با مرجع تقلید
# 3                      شرایط مرجع تقلید
# 4             مفهوم عدالت در مرجع تقلید
#
#                                          target_text  \
# 0  وضو عملی است که با شستن یا مسح اعضای خاص همراه...
# 1  ### 1️⃣ مکلَّف (فتحه روی لام مشدّد)\nکسی که با...
# 2  ### تفاوت فقیه با مرجع تقلید:\nفقیه مورد رجوع ...
# 3  ### شرایط مرجع تقلید:\n1. اجتهاد\n2. عقل و بلو...
# 4  عدالت در مرجع تقلید، حالتی نفسانی است که انسان...
#
#                                               source            editor  id
# 0  Jurisprudence Lesson Notes - Mohammad Hossein ...  Ghasem Arianpour   1
# 1                                            ChatGPT  Ghasem Arianpour   2
# 2  Jurisprudence Lesson Notes - Mohammad Hossein ...  Ghasem Arianpour   3
# 3  Jurisprudence Lesson Notes - Mohammad Hossein ...  Ghasem Arianpour   4
# 4  Jurisprudence Lesson Notes - Mohammad Hossein ...  Ghasem Arianpour   5

# %%
dataset = pd.read_parquet("parquet/Alphabet_Jurisprudence_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)
# Out:
# 🔢 Number of samples: 30
# 📝 Total number of tokens: 1350

# %% [markdown]
# ### 🌿 **Alphabet_Philologia_Dataset**

# %%
extracted_folder = "raw/dataset/Alphabet_Philologia_Dataset/"

# Filter for JSON files directly in the 'extracted_folder'
json_files = [f for f in os.listdir(extracted_folder) if f.endswith('.json')]

# Debugging: Print found JSON files
if not json_files:
    print("No JSON files found in the specified JSON source folder (extracted_folder).")
else:
    print(f"Found {len(json_files)} JSON files: {json_files}")

all_data = []

for file_name in json_files:
    json_path = os.path.join(extracted_folder, file_name)
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
        if isinstance(data, list):
            all_data.extend(data)
        elif isinstance(data, dict):
            all_data.append(data)

df_json = pd.DataFrame(all_data)

parquet_path = "parquet/Alphabet_Philologia_Dataset.parquet"
df_json.to_parquet(parquet_path, index=False)

df_loaded = pd.read_parquet(parquet_path)

df_loaded.head()
# Out:
# Found 3 JSON files: ['Cuneiform.json', 'English.json', 'Hieroglyphic.json']
#                           input_text  \
# 0                            خط میخی
# 1             تاریخچه پیدایش خط میخی
# 2  تمدن‌های استفاده کننده از خط میخی
# 3                   زمان‌های انگلیسی
# 4              زمان حال ساده انگلیسی
#
#                                          target_text             source  \
# 0  خط میخی یکی از قدیمی‌ترین نظام‌های نوشتاری جها...            ChatGPT
# 1  خط میخی، نخستین‌بار در حدود ۳۲۰۰ سال پیش از می...            ChatGPT
# 2  تمدن‌های زیادی در خاور نزدیک باستان از خط میخی...            ChatGPT
# 3  سه نوع زمان در زبان انگلیسی وجود دارد که وقوع ...  blog.faradars.org
# 4  از زمان «حال ساده» (Simple Present) برای بیان ...  blog.faradars.org
#
#              editor  id
# 0  Ghasem Arianpour   1
# 1  Ghasem Arianpour   2
# 2  Ghasem Arianpour   3
# 3  Ghasem Arianpour   1
# 4  Ghasem Arianpour   2

# %%
dataset = pd.read_parquet("parquet/Alphabet_Philologia_Dataset.parquet")

dataset.head()

num_samples = len(dataset)

total_tokens = 0
text_columns = ["input_text", "target_text"]

for col in text_columns:
    if col in dataset.columns:
        total_tokens += dataset[col].astype(str).apply(lambda x: len(x.split())).sum()

print("🔢 Number of samples:", num_samples)
print("📝 Total number of tokens:", total_tokens)
# Out:
# 🔢 Number of samples: 23
# 📝 Total number of tokens: 4075

# %% [markdown]
# ## 🟢 **EDA**

# %% [markdown]
# ### 🔴 Exploring the Dataset

# %%
base_path = "parquet/"

files = [
    "Alphabet_NLP_Dataset.parquet",
    "Alphabet_Codex_Dataset.parquet",
    "Alphabet_Jurisprudence_Dataset.parquet",
    "Alphabet_Quran_Dataset.parquet",
    "Alphabet_Science_Dataset.parquet",
    "Alphabet_Technology_Dataset.parquet",
    "Alphabet_Philologia_Dataset.parquet"
]

datasets = [pd.read_parquet(base_path + file) for file in files]

dataset = pd.concat(datasets, ignore_index=True)

dataset.head()
print("🔢 Number of samples:", len(dataset))
# Out:
# 🔢 Number of samples: 1024

# %%
sample = dataset.sample(n=1)
pprint(sample.to_dict(orient="records")[0])
# Out:
# {'editor': 'Ghasem Arianpour',
#  'id': 1,
#  'input_text': 'فیزیک کوانتومی چیست و چرا به آن نیاز داریم؟',
#  'source': 'ChatGPT',
#  'target_text': 'فیزیک کوانتومی شاخه\u200cای از فیزیک است که رفتار ماده و '
#                 'انرژی در مقیاس\u200cهای بسیار کوچک، مانند اتم\u200cها و ذرات '
#                 'زیراتمی، را بررسی می\u200cکند. این علم نشان می\u200cدهد که در '
#                 'سطح کوانتومی، انرژی و حرکت ذرات به\u200cصورت گسسته (کوانتیده) '
#                 'هستند و مفاهیمی مانند برهم\u200cنهی و عدم قطعیت نقش اساسی '
#                 'دارند. نیاز به فیزیک کوانتومی از آنجا ناشی می\u200cشود که '
#                 'بسیاری از پدیده\u200cهای اتمی و زیراتمی با قوانین فیزیک '
#                 'کلاسیک قابل توضیح نیستند و برای توسعه\u200cی فناوری\u200cهایی '
#                 'مانند نیمه\u200cرساناها، لیزرها، حسگرهای دقیق، کامپیوترهای '
#                 'کوانتومی و تحقیقات بنیادی، شناخت دقیق اصول کوانتومی ضروری '
#                 'است.'}

# %% [markdown]
# ### 🔴 Measuring RAM Usage After Dataset Loading

# %%
base_path = "parquet/"

files = [
    "Alphabet_NLP_Dataset.parquet",
    "Alphabet_Codex_Dataset.parquet",
    "Alphabet_Jurisprudence_Dataset.parquet",
    "Alphabet_Quran_Dataset.parquet",
    "Alphabet_Science_Dataset.parquet",
    "Alphabet_Technology_Dataset.parquet",
    "Alphabet_Philologia_Dataset.parquet"
]

process = psutil.Process(os.getpid())
ram_before = process.memory_info().rss  # bytes

datasets = [pd.read_parquet(base_path + file) for file in files]
dataset = pd.concat(datasets, ignore_index=True)

ram_after = process.memory_info().rss  # bytes

ram_used = ram_after - ram_before
print(f"🔹 RAM used for loading merged dataset: {ram_used / (1024**2):.2f} MB")
# Out:
# 🔹 RAM used for loading merged dataset: 4.43 MB
# 🔢 Number of samples: 1024

# %%
train_full = list(dataset["target_text"])
print(f"🔹 Number of training samples: {len(train_full)}")
# Out:
# 🔹 Number of samples: 1024

# %% [markdown]
# ### 🔴 Tokenization

# %%
base_path = "parquet/"

files = [
    "Alphabet_NLP_Dataset.parquet",
    "Alphabet_Codex_Dataset.parquet",
    "Alphabet_Jurisprudence_Dataset.parquet",
    "Alphabet_Quran_Dataset.parquet",
    "Alphabet_Science_Dataset.parquet",
    "Alphabet_Technology_Dataset.parquet",
    "Alphabet_Philologia_Dataset.parquet"
]

datasets = [pd.read_parquet(base_path + file) for file in files]
dataset = pd.concat(datasets, ignore_index=True)

texts = []

for _, row in dataset.iterrows():
    texts.append(str(row["input_text"]).replace("\u200c", "<ZWNJ>"))
    texts.append(str(row["target_text"]).replace("\u200c", "<ZWNJ>"))

tokenizer = Tokenizer(models.BPE(unk_token="|<unk>|"))

tokenizer.pre_tokenizer = pre_tokenizers.ByteLevel(
    add_prefix_space=True
)

trainer = trainers.BpeTrainer(
    vocab_size=10_000,
    special_tokens=["|<unk>|", "<|endoftext|>"],
    min_frequency=2,
)

tokenizer.train_from_iterator(texts, trainer)

tokenizer.decoder = decoders.ByteLevel(
    add_prefix_space=True,
    clean_up_tokenization_spaces=False
)

total_tokens = 0

for text in texts:
    total_tokens += len(tokenizer.encode(text).ids)

json_out = "tokenizer/bpe-tokenizer_alphabet_nlp_dataset_10,000.json"

os.makedirs("tokenizer", exist_ok=True)
tokenizer.save(json_out)

print("🎉 Tokenizer training complete!")
print(f"🔢 tokens: {total_tokens:,}")
print(f"🔹 Vocabulary size: {tokenizer.get_vocab_size():,} tokens")
# Out:
# 🎉 Tokenizer training complete!
# 🔢 Number of samples: 1,024
# 🔢 tokens: 460,896
# 🔹 Vocabulary size: 10,000 tokens

# %% [markdown]
# ### 🔴 Measuring RAM Usage After Tokenization

# %%
tokenizer = Tokenizer.from_file("tokenizer/bpe-tokenizer_alphabet_nlp_dataset_10,000.json")

# Calculate RAM usage after loading
process = psutil.Process(os.getpid())
mem_info = process.memory_info()
ram_mb = mem_info.rss / (1024 ** 2)

print(f"💾 RAM Usage after loading tokenizer: {ram_mb:.2f} MB")
# Out:
# 💾 RAM Usage after loading tokenizer: 193.86 MB

# %% [markdown]
# ### 🔴 Tokenizer Test

# %%
# Load the trained tokenizer
tokenizer = Tokenizer.from_file("tokenizer/bpe-tokenizer_alphabet_nlp_dataset_10,000.json")

# Sample text containing special tokens
sample_text = "###عنوان\n\nاین\nیک متن **مهم** با نیم‌فاصله است."

# Encode the sample text
encoded_output = tokenizer.encode(sample_text)

# Print the tokens and their decoded representation
print(f"Original text:\n{sample_text}")
print(f"Encoded tokens: {encoded_output.tokens}")
print(f"Decoded text:\n{tokenizer.decode(encoded_output.ids)}")
# Out:
# Original text:
# ###عنوان
#
# این
# یک متن **مهم** با نیم‌فاصله است.
# Encoded tokens: ['Ġ###', 'Ø¹ÙĨÙĪØ§ÙĨ', 'Ċ', 'Ċ', 'Ø§ÛĮÙĨ', 'Ċ', 'ÛĮÚ©', 'ĠÙħØªÙĨ', 'Ġ**', 'ÙħÙĩÙħ', '**', 'ĠØ¨Ø§', 'ĠÙĨ', 'ÛĮÙħ', 'âĢ', 'Į', 'Ùģ', 'Ø§ØµÙĦÙĩ', 'ĠØ§Ø³Øª', '.']
# Decoded text:
#  ###عنوان
#
# این
# یک متن **مهم** با نیم‌فاصله است.
